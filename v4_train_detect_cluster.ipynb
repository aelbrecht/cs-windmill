# %%
import numpy as np
import rasterio
from sklearn.model_selection import train_test_split
from tensorflow import keras

from functions.image import get_filtered_satellite_float32, remove_noise_satellite


def get_processed_image(coord):
    return get_filtered_satellite_float32(coord, block_size, img_raw, dataset_raw)

# %%
# haal dataset op waar je molens kan zien
dataset_raw = rasterio.open("./data/crs.tiff")
img_raw = dataset_raw.read(1)
block_size = 30

# %%
from cv2 import cv2 as cv

# haal dataset op waar we kunnen afleiden of we land of water zien
dataset_land = rasterio.open(
    "./data/E000N60_PROBAV_LC100_global_v3.0.1_2019-nrt_Discrete-Classification-map_EPSG-4326.tif")
img_land = dataset_land.read(1)

# we zetten hier alles buiten land op 0
img_land[img_land != 200] = 0  # 200 is ocean index
img_land[img_land == 200] = 1

# dilate om kustlijnen uit resultaat te laten
kernel = np.ones((5, 5), np.uint8)
img_land = cv.erode(img_land, kernel, iterations=5)

# %%
import glob

examples = glob.glob("./examples/*/*.png", recursive=True)

# %%
import imageio

X = []
Y = []

valid = ["windmills", "boats", "ocean", "beach"]
target = ["windmills", "boats"]

for path in examples:

    category = path.split("/")[2]
    if category not in valid:
        continue

    src = imageio.imread(path)
    src = np.expand_dims(remove_noise_satellite(src) / 255.0, -1)

    # import images oriented 4 ways
    for i in range(4):
        X.append(np.rot90(src.copy(), i))
        if category in target:
            Y.append(1)
        else:
            Y.append(0)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

X_train = np.stack(X_train)
X_test = np.stack(X_test)
Y_train = keras.utils.to_categorical(Y_train, 2)
Y_test = keras.utils.to_categorical(Y_test, 2)

# %%
from keras import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense

model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, validation_split=0.2, epochs=100)
# Out:
# Epoch 1/100
# 107/107 [==============================] - 1s 5ms/step - loss: 0.3841 - accuracy: 0.8501 - val_loss: 0.3731 - val_accuracy: 0.8558
# Epoch 2/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.3264 - accuracy: 0.8756 - val_loss: 0.3406 - val_accuracy: 0.8687
# Epoch 3/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.3176 - accuracy: 0.8750 - val_loss: 0.3291 - val_accuracy: 0.8710
# Epoch 4/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.3134 - accuracy: 0.8768 - val_loss: 0.3321 - val_accuracy: 0.8664
# Epoch 5/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.3174 - accuracy: 0.8747 - val_loss: 0.3322 - val_accuracy: 0.8664
# Epoch 6/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.3082 - accuracy: 0.8762 - val_loss: 0.3318 - val_accuracy: 0.8664
# Epoch 7/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.3040 - accuracy: 0.8800 - val_loss: 0.3515 - val_accuracy: 0.8581
# Epoch 8/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.3020 - accuracy: 0.8780 - val_loss: 0.3183 - val_accuracy: 0.8816
# Epoch 9/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2981 - accuracy: 0.8830 - val_loss: 0.3176 - val_accuracy: 0.8781
# Epoch 10/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2995 - accuracy: 0.8818 - val_loss: 0.3190 - val_accuracy: 0.8792
# Epoch 11/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2965 - accuracy: 0.8856 - val_loss: 0.3191 - val_accuracy: 0.8792
# Epoch 12/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.8859 - val_loss: 0.3064 - val_accuracy: 0.8816
# Epoch 13/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2894 - accuracy: 0.8841 - val_loss: 0.3051 - val_accuracy: 0.8792
# Epoch 14/100
# 107/107 [==============================] - 1s 5ms/step - loss: 0.2899 - accuracy: 0.8874 - val_loss: 0.3008 - val_accuracy: 0.8816
# Epoch 15/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2906 - accuracy: 0.8865 - val_loss: 0.3018 - val_accuracy: 0.8804
# Epoch 16/100
# 107/107 [==============================] - 1s 6ms/step - loss: 0.2839 - accuracy: 0.8871 - val_loss: 0.2982 - val_accuracy: 0.8828
# Epoch 17/100
# 107/107 [==============================] - 1s 5ms/step - loss: 0.2753 - accuracy: 0.8900 - val_loss: 0.3219 - val_accuracy: 0.8710
# Epoch 18/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2767 - accuracy: 0.8891 - val_loss: 0.2898 - val_accuracy: 0.8839
# Epoch 19/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2750 - accuracy: 0.8921 - val_loss: 0.3140 - val_accuracy: 0.8710
# Epoch 20/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2674 - accuracy: 0.8950 - val_loss: 0.2933 - val_accuracy: 0.8804
# Epoch 21/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2690 - accuracy: 0.8915 - val_loss: 0.2903 - val_accuracy: 0.8839
# Epoch 22/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2645 - accuracy: 0.8915 - val_loss: 0.2857 - val_accuracy: 0.8886
# Epoch 23/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2639 - accuracy: 0.8950 - val_loss: 0.3081 - val_accuracy: 0.8839
# Epoch 24/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2632 - accuracy: 0.8973 - val_loss: 0.2992 - val_accuracy: 0.8757
# Epoch 25/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2650 - accuracy: 0.8956 - val_loss: 0.2947 - val_accuracy: 0.8851
# Epoch 26/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2591 - accuracy: 0.8953 - val_loss: 0.2896 - val_accuracy: 0.8757
# Epoch 27/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2535 - accuracy: 0.8970 - val_loss: 0.2842 - val_accuracy: 0.8828
# Epoch 28/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2466 - accuracy: 0.9003 - val_loss: 0.2705 - val_accuracy: 0.8875
# Epoch 29/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2459 - accuracy: 0.9014 - val_loss: 0.2672 - val_accuracy: 0.8863
# Epoch 30/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2441 - accuracy: 0.9082 - val_loss: 0.2929 - val_accuracy: 0.8781
# Epoch 31/100
# 107/107 [==============================] - 0s 5ms/step - loss: 0.2458 - accuracy: 0.9026 - val_loss: 0.2673 - val_accuracy: 0.8886
# Epoch 32/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2406 - accuracy: 0.9067 - val_loss: 0.2715 - val_accuracy: 0.8933
# Epoch 33/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2332 - accuracy: 0.9061 - val_loss: 0.2599 - val_accuracy: 0.8910
# Epoch 34/100
# 107/107 [==============================] - 1s 5ms/step - loss: 0.2273 - accuracy: 0.9108 - val_loss: 0.2645 - val_accuracy: 0.8910
# Epoch 35/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2282 - accuracy: 0.9126 - val_loss: 0.3412 - val_accuracy: 0.8699
# Epoch 36/100
# 107/107 [==============================] - 1s 5ms/step - loss: 0.2400 - accuracy: 0.9058 - val_loss: 0.2832 - val_accuracy: 0.8769
# Epoch 37/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2220 - accuracy: 0.9135 - val_loss: 0.2512 - val_accuracy: 0.8968
# Epoch 38/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2188 - accuracy: 0.9149 - val_loss: 0.2584 - val_accuracy: 0.8945
# Epoch 39/100
# 107/107 [==============================] - 0s 5ms/step - loss: 0.2115 - accuracy: 0.9161 - val_loss: 0.2671 - val_accuracy: 0.8816
# Epoch 40/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2065 - accuracy: 0.9196 - val_loss: 0.2487 - val_accuracy: 0.8968
# Epoch 41/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2142 - accuracy: 0.9152 - val_loss: 0.2415 - val_accuracy: 0.8980
# Epoch 42/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2105 - accuracy: 0.9187 - val_loss: 0.2455 - val_accuracy: 0.8945
# Epoch 43/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2053 - accuracy: 0.9211 - val_loss: 0.2410 - val_accuracy: 0.9015
# Epoch 44/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1955 - accuracy: 0.9252 - val_loss: 0.2403 - val_accuracy: 0.8980
# Epoch 45/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1967 - accuracy: 0.9214 - val_loss: 0.2438 - val_accuracy: 0.9015
# Epoch 46/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1848 - accuracy: 0.9337 - val_loss: 0.2586 - val_accuracy: 0.8886
# Epoch 47/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1910 - accuracy: 0.9290 - val_loss: 0.2374 - val_accuracy: 0.9109
# Epoch 48/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 0.9261 - val_loss: 0.2266 - val_accuracy: 0.9050
# Epoch 49/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1829 - accuracy: 0.9302 - val_loss: 0.2452 - val_accuracy: 0.9027
# Epoch 50/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1879 - accuracy: 0.9290 - val_loss: 0.2606 - val_accuracy: 0.9015
# Epoch 51/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1804 - accuracy: 0.9337 - val_loss: 0.2330 - val_accuracy: 0.9050
# Epoch 52/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1755 - accuracy: 0.9355 - val_loss: 0.2290 - val_accuracy: 0.9074
# Epoch 53/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1722 - accuracy: 0.9361 - val_loss: 0.2267 - val_accuracy: 0.9109
# Epoch 54/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1704 - accuracy: 0.9375 - val_loss: 0.2388 - val_accuracy: 0.9039
# Epoch 55/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1703 - accuracy: 0.9340 - val_loss: 0.2181 - val_accuracy: 0.9144
# Epoch 56/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1652 - accuracy: 0.9405 - val_loss: 0.2107 - val_accuracy: 0.9191
# Epoch 57/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1622 - accuracy: 0.9393 - val_loss: 0.2351 - val_accuracy: 0.9109
# Epoch 58/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1615 - accuracy: 0.9369 - val_loss: 0.2181 - val_accuracy: 0.9132
# Epoch 59/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1574 - accuracy: 0.9390 - val_loss: 0.2080 - val_accuracy: 0.9226
# Epoch 60/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1555 - accuracy: 0.9419 - val_loss: 0.2214 - val_accuracy: 0.9109
# Epoch 61/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1511 - accuracy: 0.9422 - val_loss: 0.2325 - val_accuracy: 0.9121
# Epoch 62/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1553 - accuracy: 0.9422 - val_loss: 0.2162 - val_accuracy: 0.9097
# Epoch 63/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1521 - accuracy: 0.9437 - val_loss: 0.2075 - val_accuracy: 0.9226
# Epoch 64/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1421 - accuracy: 0.9463 - val_loss: 0.2054 - val_accuracy: 0.9203
# Epoch 65/100
# 107/107 [==============================] - 1s 5ms/step - loss: 0.1409 - accuracy: 0.9454 - val_loss: 0.2081 - val_accuracy: 0.9203
# Epoch 66/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1395 - accuracy: 0.9451 - val_loss: 0.2779 - val_accuracy: 0.9039
# Epoch 67/100
# 107/107 [==============================] - 0s 5ms/step - loss: 0.1377 - accuracy: 0.9472 - val_loss: 0.2059 - val_accuracy: 0.9215
# Epoch 68/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9490 - val_loss: 0.2808 - val_accuracy: 0.9015
# Epoch 69/100
# 107/107 [==============================] - 0s 5ms/step - loss: 0.1296 - accuracy: 0.9539 - val_loss: 0.1993 - val_accuracy: 0.9250
# Epoch 70/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1366 - accuracy: 0.9466 - val_loss: 0.1974 - val_accuracy: 0.9285
# Epoch 71/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1319 - accuracy: 0.9457 - val_loss: 0.2143 - val_accuracy: 0.9203
# Epoch 72/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1277 - accuracy: 0.9498 - val_loss: 0.2231 - val_accuracy: 0.9203
# Epoch 73/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1274 - accuracy: 0.9528 - val_loss: 0.2187 - val_accuracy: 0.9168
# Epoch 74/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.9531 - val_loss: 0.2413 - val_accuracy: 0.9156
# Epoch 75/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1122 - accuracy: 0.9551 - val_loss: 0.1987 - val_accuracy: 0.9273
# Epoch 76/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9551 - val_loss: 0.1979 - val_accuracy: 0.9261
# Epoch 77/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1149 - accuracy: 0.9557 - val_loss: 0.2197 - val_accuracy: 0.9250
# Epoch 78/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1177 - accuracy: 0.9537 - val_loss: 0.2128 - val_accuracy: 0.9226
# Epoch 79/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1101 - accuracy: 0.9581 - val_loss: 0.2008 - val_accuracy: 0.9273
# Epoch 80/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1040 - accuracy: 0.9604 - val_loss: 0.2238 - val_accuracy: 0.9203
# Epoch 81/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1098 - accuracy: 0.9583 - val_loss: 0.2070 - val_accuracy: 0.9203
# Epoch 82/100
# 107/107 [==============================] - 1s 5ms/step - loss: 0.1068 - accuracy: 0.9583 - val_loss: 0.2084 - val_accuracy: 0.9285
# Epoch 83/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1074 - accuracy: 0.9581 - val_loss: 0.2085 - val_accuracy: 0.9226
# Epoch 84/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9575 - val_loss: 0.2038 - val_accuracy: 0.9203
# Epoch 85/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1000 - accuracy: 0.9610 - val_loss: 0.1936 - val_accuracy: 0.9273
# Epoch 86/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1026 - accuracy: 0.9598 - val_loss: 0.2348 - val_accuracy: 0.9261
# Epoch 87/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1040 - accuracy: 0.9610 - val_loss: 0.1949 - val_accuracy: 0.9355
# Epoch 88/100
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0991 - accuracy: 0.9619 - val_loss: 0.2011 - val_accuracy: 0.9297
# Epoch 89/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0850 - accuracy: 0.9707 - val_loss: 0.2175 - val_accuracy: 0.9273
# Epoch 90/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0937 - accuracy: 0.9636 - val_loss: 0.2124 - val_accuracy: 0.9203
# Epoch 91/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0867 - accuracy: 0.9654 - val_loss: 0.1883 - val_accuracy: 0.9273
# Epoch 92/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0895 - accuracy: 0.9692 - val_loss: 0.2300 - val_accuracy: 0.9226
# Epoch 93/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9642 - val_loss: 0.2225 - val_accuracy: 0.9226
# Epoch 94/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0940 - accuracy: 0.9666 - val_loss: 0.2147 - val_accuracy: 0.9297
# Epoch 95/100
# 107/107 [==============================] - 0s 5ms/step - loss: 0.0904 - accuracy: 0.9671 - val_loss: 0.1850 - val_accuracy: 0.9355
# Epoch 96/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0985 - accuracy: 0.9622 - val_loss: 0.2442 - val_accuracy: 0.9132
# Epoch 97/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0933 - accuracy: 0.9648 - val_loss: 0.1871 - val_accuracy: 0.9308
# Epoch 98/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0793 - accuracy: 0.9730 - val_loss: 0.2000 - val_accuracy: 0.9297
# Epoch 99/100
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0783 - accuracy: 0.9704 - val_loss: 0.2177 - val_accuracy: 0.9250
# Epoch 100/100
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0866 - accuracy: 0.9686 - val_loss: 0.2008 - val_accuracy: 0.9308

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.evaluate(X_test, Y_test, verbose=2)
# Out:
# 34/34 - 0s - loss: 0.2011 - accuracy: 0.9287 - 90ms/epoch - 3ms/step
# [0.20109346508979797, 0.9287054538726807]

# %%
# confusion matrix

import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

Y_pred = model.predict(X_test)
cm = confusion_matrix([np.argmax(a) for a in Y_test], [np.argmax(a) for a in Y_pred])

df_cm = pd.DataFrame(cm, index=["Water", "Object"], columns=["Water", "Object"])
plt.figure(figsize=(10, 7))
sn.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
def detect_windmills():
    needles = []
    step_size = 15

    [h, w] = dataset_raw.shape
    for xx in range(block_size // 2, w - block_size // 2, step_size):
        for yy in range(block_size // 2, h - block_size // 2, step_size):
            cc = dataset_raw.transform * (yy, xx)
            lx, ly = dataset_land.index(cc[0], cc[1])
            if img_land[lx, ly] != 1:
                continue
            needles.append({'lon': cc[0], 'lat': cc[1]})

    test_images = np.stack([get_processed_image(coord) for coord in needles])
    results = model.predict(test_images)
    coords = []
    for i, result in enumerate(results):
        if i % 1000:
            print(f"{i}/{len(results)}")
        if result[1] > result[0]:
            coords.append(needles[i])
    return coords


def plot_windmills(left_top_coord, size=(1200, 800), intensity=1):
    (img_h, img_w) = size
    left_top_x, left_top_y = dataset_raw.index(left_top_coord[0], left_top_coord[1])
    needles = []
    step_size = 15

    x_count = ((img_h - block_size) // step_size)
    for xx in range(left_top_x + block_size // 2, left_top_x + img_w - block_size // 2, step_size):
        for yy in range(left_top_y + block_size // 2, left_top_y + img_h - block_size // 2, step_size):
            cc = dataset_raw.transform * (yy, xx)
            lx, ly = dataset_land.index(cc[0], cc[1])
            if img_land[lx, ly] != 1:
                continue
            needles.append({'lon': cc[0], 'lat': cc[1]})

    test_images = np.stack([get_processed_image(coord) for coord in needles])
    results = model.predict(test_images)

    from matplotlib import pyplot as plt

    search_space = np.copy(img_raw[left_top_x:left_top_x + img_w, left_top_y:left_top_y + img_h])
    search_space = search_space ** (1 / 4)
    highlight = np.max(search_space) * 0.75 * intensity

    found = 0
    previous_i = 0
    coords = []
    found_i = []
    for i, result in enumerate(results):
        if result[1] > result[0]:
            if i - previous_i <= 2:
                continue
            if i - x_count in found_i or (i - (x_count * 2)) in found_i or (i + 1 - x_count) in found_i or (
                    i - 1 - x_count) in found_i:
                continue
            found += 1
            previous_i = i
            found_i.append(i)
            coord = needles[i]
            xx, yy = dataset_raw.index(coord['lon'], coord['lat'])
            xx -= left_top_x
            yy -= left_top_y

            search_space[xx - block_size // 2:xx + block_size // 2, yy - block_size // 2] = highlight
            search_space[xx - block_size // 2:xx + block_size // 2, yy + block_size // 2] = highlight
            search_space[xx - block_size // 2, yy - block_size // 2:yy + block_size // 2] = highlight
            search_space[xx + block_size // 2, yy - block_size // 2:yy + block_size // 2] = highlight
            coords.append(coord)

    print("found {} windmills".format(found))

    plt.rcParams['figure.figsize'] = [20, 10]
    plt.imshow(search_space)

    return coords

# %%
# vb boten
_ = plot_windmills((2.56834, 51.48205))
# Out:
# found 54 windmills

# %%
# vb molens
_ = plot_windmills((1.85730, 52.01960))
# Out:
# found 128 windmills

# %%
# vb kust
_ = plot_windmills((1.12835, 51.90720))
# Out:
# found 0 windmills
# []

# %%
from sklearn import cluster
import matplotlib.cm as cm

colors = np.array(['r', 'g', 'b', 'y', 'c', 't'])
colors = cm.rainbow(np.linspace(0, 1, 50))


def apply(X, algo):
    algo.fit(X)
    labels = algo.labels_.astype(np.int)
    plt.scatter(X[:, 0], X[:, 1], color=colors[labels])
    plt.show()
    return labels


df = pd.DataFrame(coords)
X = df.to_numpy()

#labels = apply(X, cluster.KMeans(n_clusters=4))

labels = apply(X, cluster.DBSCAN(eps=.06))
#apply(X, cluster.SpectralClustering(n_clusters=2, affinity="nearest_neighbors"))

cluster_map = pd.DataFrame()
cluster_map['X'] = X[:, 0]
cluster_map['Y'] = X[:, 1]
cluster_map['cluster'] = labels

print(cluster_map)
# Out:
# /tmp/ipykernel_16206/3793571605.py:10: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   labels = algo.labels_.astype(np.int)
#             X          Y  cluster
# 0    1.744898  52.183574       -1
# 1    1.744898  52.181470       -1
# 2    1.959468  52.173056        0
# 3    1.906877  52.170952        0
# 4    1.961572  52.170952        0
# ..        ...        ...      ...
# 644  1.473530  51.632423        5
# 645  1.488255  51.632423        5
# 646  1.494566  51.632423        5
# 647  1.513499  51.632423        5
# 648  1.555571  51.632423        5
#
# [649 rows x 3 columns]

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer

# Generate synthetic dataset with 8 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)
# X, y = make_blobs(n_samples=1000, centers=5, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(4, 10))

visualizer.fit(X)  # Fit the data to the visualizer
visualizer.show()  # Finalize and render the figure

from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.cluster import KMeans

model = SilhouetteVisualizer(KMeans(5))
model.fit(X)
model.show()

from yellowbrick.cluster import InterclusterDistance

visualizer = InterclusterDistance(model)
visualizer.fit(X)  # Fit the data to the visualizer
visualizer.show()  # Finalize and render the figure

print(len(X))
# Out:
# Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x7fea921acc10>
# Traceback (most recent call last):
#   File "/home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/threadpoolctl.py", line 548, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/threadpoolctl.py", line 669, in _make_controller_from_path
#     lib_controller = lib_controller_class(
#   File "/home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/threadpoolctl.py", line 786, in __init__
#     super().__init__(**kwargs)
#   File "/home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/threadpoolctl.py", line 754, in __init__
#     self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
#   File "/usr/lib/python3.9/ctypes/__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: /home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/numpy.libs/libopenblasp-r0-2d23e62b.3.17.so: cannot open shared object file: No such file or directory
# 649

# %%
from shapely.geometry import LineString
import geopandas as gpd


def bounding_box(x_coordinates, y_coordinates):
    # x_coordinates, y_coordinates = zip(*points)
    return [(min(x_coordinates), min(y_coordinates)), (max(x_coordinates), max(y_coordinates))]


list_lon = []
list_lat = []
list_geom = []

column_values = cluster_map["cluster"].values
clusters = np.unique(column_values)
bboxs = []
for cluster in clusters:
    if (cluster_map[cluster_map.cluster == cluster].shape[0] <= 20):
        continue
    bboxs.append(bounding_box(cluster_map[cluster_map.cluster == cluster]['X'],
                              cluster_map[cluster_map.cluster == cluster]['Y']))

l_lats = []
l_lons = []
boxes = []
for bbox in bboxs:
    l_lats.append(bbox[0][0])
    l_lats.append(bbox[1][0])
    l_lats.append(bbox[1][0])
    l_lats.append(bbox[0][0])
    l_lats.append(bbox[0][0])
    l_lons.append(bbox[0][1])
    l_lons.append(bbox[0][1])
    l_lons.append(bbox[1][1])
    l_lons.append(bbox[1][1])
    l_lons.append(bbox[0][1])

    bb = gpd.points_from_xy(l_lats, l_lons, crs="EPSG:4326")

    boxes.append(LineString(bb))
    l_lats = []
    l_lons = []

df_result = gpd.GeoDataFrame({
    'geometry': boxes
})

df_result['geometry']
from shapely.ops import unary_union

cu = unary_union(df_result['geometry']);
df2_result = gpd.GeoDataFrame({
    'geometry': cu
})

df2_result.crs = 'epsg:4326'
df2_result.to_file("result.shp")
