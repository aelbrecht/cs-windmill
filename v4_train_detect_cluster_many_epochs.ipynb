# %%
import numpy as np
import rasterio
from sklearn.model_selection import train_test_split
from tensorflow import keras

from functions.image import get_filtered_satellite_float32, remove_noise_satellite


def get_processed_image(coord):
    return get_filtered_satellite_float32(coord, block_size, img_raw, dataset_raw)

# %%
# haal dataset op waar je molens kan zien
dataset_raw = rasterio.open("./data/crs.tiff")
img_raw = dataset_raw.read(1)
block_size = 30

# %%
from cv2 import cv2 as cv

# haal dataset op waar we kunnen afleiden of we land of water zien
dataset_land = rasterio.open(
    "./data/E000N60_PROBAV_LC100_global_v3.0.1_2019-nrt_Discrete-Classification-map_EPSG-4326.tif")
img_land = dataset_land.read(1)

# we zetten hier alles buiten land op 0
img_land[img_land != 200] = 0  # 200 is ocean index
img_land[img_land == 200] = 1

# dilate om kustlijnen uit resultaat te laten
kernel = np.ones((5, 5), np.uint8)
img_land = cv.erode(img_land, kernel, iterations=5)

# %%
import glob

examples = glob.glob("./examples/*/*.png", recursive=True)

# %%
import imageio

X = []
Y = []

valid = ["windmills", "boats", "ocean", "beach"]
target = ["windmills", "boats"]

for path in examples:

    category = path.split("/")[2]
    if category not in valid:
        continue

    src = imageio.imread(path)
    src = np.expand_dims(remove_noise_satellite(src) / 255.0, -1)

    # import images oriented 4 ways
    for i in range(4):
        X.append(np.rot90(src.copy(), i))
        if category in target:
            Y.append(1)
        else:
            Y.append(0)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

X_train = np.stack(X_train)
X_test = np.stack(X_test)
Y_train = keras.utils.to_categorical(Y_train, 2)
Y_test = keras.utils.to_categorical(Y_test, 2)

# %%
from keras import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense

model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, validation_split=0.2, epochs=200)
# Out:
# Epoch 1/200
# 107/107 [==============================] - 1s 5ms/step - loss: 0.3861 - accuracy: 0.8442 - val_loss: 0.3319 - val_accuracy: 0.8769
# Epoch 2/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.3209 - accuracy: 0.8803 - val_loss: 0.3358 - val_accuracy: 0.8804
# Epoch 3/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.3199 - accuracy: 0.8797 - val_loss: 0.3283 - val_accuracy: 0.8746
# Epoch 4/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.3101 - accuracy: 0.8815 - val_loss: 0.3296 - val_accuracy: 0.8734
# Epoch 5/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.3086 - accuracy: 0.8844 - val_loss: 0.3206 - val_accuracy: 0.8839
# Epoch 6/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.3010 - accuracy: 0.8882 - val_loss: 0.3179 - val_accuracy: 0.8757
# Epoch 7/200
# 107/107 [==============================] - 0s 5ms/step - loss: 0.3030 - accuracy: 0.8847 - val_loss: 0.3190 - val_accuracy: 0.8886
# Epoch 8/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.3035 - accuracy: 0.8818 - val_loss: 0.3202 - val_accuracy: 0.8734
# Epoch 9/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2980 - accuracy: 0.8897 - val_loss: 0.3114 - val_accuracy: 0.8828
# Epoch 10/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2941 - accuracy: 0.8877 - val_loss: 0.3105 - val_accuracy: 0.8839
# Epoch 11/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2949 - accuracy: 0.8903 - val_loss: 0.3087 - val_accuracy: 0.8851
# Epoch 12/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2847 - accuracy: 0.8915 - val_loss: 0.3058 - val_accuracy: 0.8875
# Epoch 13/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.8900 - val_loss: 0.3163 - val_accuracy: 0.8839
# Epoch 14/200
# 107/107 [==============================] - 0s 5ms/step - loss: 0.2863 - accuracy: 0.8891 - val_loss: 0.3046 - val_accuracy: 0.8886
# Epoch 15/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2795 - accuracy: 0.8959 - val_loss: 0.3028 - val_accuracy: 0.8851
# Epoch 16/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2740 - accuracy: 0.8938 - val_loss: 0.3016 - val_accuracy: 0.8875
# Epoch 17/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.8932 - val_loss: 0.3013 - val_accuracy: 0.8804
# Epoch 18/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2721 - accuracy: 0.8932 - val_loss: 0.2997 - val_accuracy: 0.8875
# Epoch 19/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2699 - accuracy: 0.8944 - val_loss: 0.2994 - val_accuracy: 0.8898
# Epoch 20/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2697 - accuracy: 0.8944 - val_loss: 0.2975 - val_accuracy: 0.8804
# Epoch 21/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2638 - accuracy: 0.8985 - val_loss: 0.3025 - val_accuracy: 0.8886
# Epoch 22/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2684 - accuracy: 0.9017 - val_loss: 0.2919 - val_accuracy: 0.8910
# Epoch 23/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2642 - accuracy: 0.9003 - val_loss: 0.2962 - val_accuracy: 0.8968
# Epoch 24/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2543 - accuracy: 0.9017 - val_loss: 0.2844 - val_accuracy: 0.8980
# Epoch 25/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2478 - accuracy: 0.9011 - val_loss: 0.2844 - val_accuracy: 0.8898
# Epoch 26/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2591 - accuracy: 0.8991 - val_loss: 0.2973 - val_accuracy: 0.8980
# Epoch 27/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2480 - accuracy: 0.9067 - val_loss: 0.2871 - val_accuracy: 0.8980
# Epoch 28/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2470 - accuracy: 0.9070 - val_loss: 0.3039 - val_accuracy: 0.8769
# Epoch 29/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2435 - accuracy: 0.9094 - val_loss: 0.2831 - val_accuracy: 0.8992
# Epoch 30/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2435 - accuracy: 0.9070 - val_loss: 0.2827 - val_accuracy: 0.9015
# Epoch 31/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2378 - accuracy: 0.9064 - val_loss: 0.2800 - val_accuracy: 0.8957
# Epoch 32/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2289 - accuracy: 0.9152 - val_loss: 0.2897 - val_accuracy: 0.9004
# Epoch 33/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2266 - accuracy: 0.9117 - val_loss: 0.2838 - val_accuracy: 0.9039
# Epoch 34/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2253 - accuracy: 0.9199 - val_loss: 0.2804 - val_accuracy: 0.9039
# Epoch 35/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2205 - accuracy: 0.9164 - val_loss: 0.2670 - val_accuracy: 0.9027
# Epoch 36/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2145 - accuracy: 0.9170 - val_loss: 0.2747 - val_accuracy: 0.9039
# Epoch 37/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2136 - accuracy: 0.9202 - val_loss: 0.3043 - val_accuracy: 0.8933
# Epoch 38/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2165 - accuracy: 0.9173 - val_loss: 0.2745 - val_accuracy: 0.9050
# Epoch 39/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2105 - accuracy: 0.9211 - val_loss: 0.2608 - val_accuracy: 0.9097
# Epoch 40/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2123 - accuracy: 0.9158 - val_loss: 0.2826 - val_accuracy: 0.8933
# Epoch 41/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.2034 - accuracy: 0.9229 - val_loss: 0.2873 - val_accuracy: 0.9004
# Epoch 42/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.2036 - accuracy: 0.9214 - val_loss: 0.2683 - val_accuracy: 0.9027
# Epoch 43/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1953 - accuracy: 0.9278 - val_loss: 0.2713 - val_accuracy: 0.8992
# Epoch 44/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1925 - accuracy: 0.9287 - val_loss: 0.2597 - val_accuracy: 0.8980
# Epoch 45/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1867 - accuracy: 0.9284 - val_loss: 0.2672 - val_accuracy: 0.8980
# Epoch 46/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1893 - accuracy: 0.9278 - val_loss: 0.2665 - val_accuracy: 0.9097
# Epoch 47/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1947 - accuracy: 0.9226 - val_loss: 0.2656 - val_accuracy: 0.9086
# Epoch 48/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1903 - accuracy: 0.9231 - val_loss: 0.3080 - val_accuracy: 0.8875
# Epoch 49/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1783 - accuracy: 0.9302 - val_loss: 0.2852 - val_accuracy: 0.9062
# Epoch 50/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1730 - accuracy: 0.9352 - val_loss: 0.2546 - val_accuracy: 0.9109
# Epoch 51/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1708 - accuracy: 0.9363 - val_loss: 0.2552 - val_accuracy: 0.9097
# Epoch 52/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1714 - accuracy: 0.9358 - val_loss: 0.2620 - val_accuracy: 0.9074
# Epoch 53/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1728 - accuracy: 0.9331 - val_loss: 0.2598 - val_accuracy: 0.9132
# Epoch 54/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1627 - accuracy: 0.9378 - val_loss: 0.2563 - val_accuracy: 0.9121
# Epoch 55/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1603 - accuracy: 0.9358 - val_loss: 0.2781 - val_accuracy: 0.9156
# Epoch 56/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1615 - accuracy: 0.9387 - val_loss: 0.2884 - val_accuracy: 0.9039
# Epoch 57/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1617 - accuracy: 0.9425 - val_loss: 0.2494 - val_accuracy: 0.9132
# Epoch 58/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1591 - accuracy: 0.9375 - val_loss: 0.2650 - val_accuracy: 0.9191
# Epoch 59/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 0.9434 - val_loss: 0.2471 - val_accuracy: 0.9121
# Epoch 60/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1535 - accuracy: 0.9366 - val_loss: 0.2523 - val_accuracy: 0.9121
# Epoch 61/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1553 - accuracy: 0.9419 - val_loss: 0.2572 - val_accuracy: 0.9132
# Epoch 62/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1415 - accuracy: 0.9443 - val_loss: 0.2535 - val_accuracy: 0.9168
# Epoch 63/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.9434 - val_loss: 0.2469 - val_accuracy: 0.9109
# Epoch 64/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1491 - accuracy: 0.9416 - val_loss: 0.2536 - val_accuracy: 0.9132
# Epoch 65/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1449 - accuracy: 0.9449 - val_loss: 0.2484 - val_accuracy: 0.9132
# Epoch 66/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1393 - accuracy: 0.9446 - val_loss: 0.2480 - val_accuracy: 0.9144
# Epoch 67/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1389 - accuracy: 0.9472 - val_loss: 0.2659 - val_accuracy: 0.9132
# Epoch 68/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1456 - accuracy: 0.9428 - val_loss: 0.2480 - val_accuracy: 0.9144
# Epoch 69/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.9519 - val_loss: 0.2585 - val_accuracy: 0.9156
# Epoch 70/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1355 - accuracy: 0.9534 - val_loss: 0.2525 - val_accuracy: 0.9168
# Epoch 71/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.9498 - val_loss: 0.2781 - val_accuracy: 0.9144
# Epoch 72/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1376 - accuracy: 0.9457 - val_loss: 0.2501 - val_accuracy: 0.9203
# Epoch 73/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1170 - accuracy: 0.9560 - val_loss: 0.2884 - val_accuracy: 0.9144
# Epoch 74/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1250 - accuracy: 0.9522 - val_loss: 0.2580 - val_accuracy: 0.9168
# Epoch 75/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9554 - val_loss: 0.2423 - val_accuracy: 0.9250
# Epoch 76/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1215 - accuracy: 0.9513 - val_loss: 0.2394 - val_accuracy: 0.9191
# Epoch 77/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9534 - val_loss: 0.2635 - val_accuracy: 0.9144
# Epoch 78/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9569 - val_loss: 0.2459 - val_accuracy: 0.9179
# Epoch 79/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1099 - accuracy: 0.9581 - val_loss: 0.2308 - val_accuracy: 0.9203
# Epoch 80/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.9566 - val_loss: 0.2341 - val_accuracy: 0.9238
# Epoch 81/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.9595 - val_loss: 0.2485 - val_accuracy: 0.9168
# Epoch 82/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1124 - accuracy: 0.9545 - val_loss: 0.2452 - val_accuracy: 0.9238
# Epoch 83/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1062 - accuracy: 0.9627 - val_loss: 0.2497 - val_accuracy: 0.9261
# Epoch 84/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9545 - val_loss: 0.2351 - val_accuracy: 0.9261
# Epoch 85/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1056 - accuracy: 0.9607 - val_loss: 0.2621 - val_accuracy: 0.9238
# Epoch 86/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9625 - val_loss: 0.2625 - val_accuracy: 0.9156
# Epoch 87/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1042 - accuracy: 0.9619 - val_loss: 0.2978 - val_accuracy: 0.9238
# Epoch 88/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1005 - accuracy: 0.9625 - val_loss: 0.2580 - val_accuracy: 0.9215
# Epoch 89/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9642 - val_loss: 0.2658 - val_accuracy: 0.9191
# Epoch 90/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0918 - accuracy: 0.9657 - val_loss: 0.2557 - val_accuracy: 0.9250
# Epoch 91/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0918 - accuracy: 0.9642 - val_loss: 0.2627 - val_accuracy: 0.9238
# Epoch 92/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0951 - accuracy: 0.9648 - val_loss: 0.2408 - val_accuracy: 0.9238
# Epoch 93/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9633 - val_loss: 0.2866 - val_accuracy: 0.9168
# Epoch 94/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1015 - accuracy: 0.9604 - val_loss: 0.2615 - val_accuracy: 0.9215
# Epoch 95/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.9598 - val_loss: 0.2327 - val_accuracy: 0.9308
# Epoch 96/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9648 - val_loss: 0.2922 - val_accuracy: 0.9203
# Epoch 97/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9633 - val_loss: 0.2496 - val_accuracy: 0.9226
# Epoch 98/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0922 - accuracy: 0.9627 - val_loss: 0.2599 - val_accuracy: 0.9238
# Epoch 99/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0897 - accuracy: 0.9663 - val_loss: 0.2390 - val_accuracy: 0.9273
# Epoch 100/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0908 - accuracy: 0.9686 - val_loss: 0.2246 - val_accuracy: 0.9261
# Epoch 101/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0856 - accuracy: 0.9680 - val_loss: 0.2350 - val_accuracy: 0.9273
# Epoch 102/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0905 - accuracy: 0.9666 - val_loss: 0.2363 - val_accuracy: 0.9297
# Epoch 103/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0851 - accuracy: 0.9660 - val_loss: 0.2317 - val_accuracy: 0.9273
# Epoch 104/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9748 - val_loss: 0.2450 - val_accuracy: 0.9261
# Epoch 105/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0746 - accuracy: 0.9754 - val_loss: 0.2321 - val_accuracy: 0.9238
# Epoch 106/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9739 - val_loss: 0.2564 - val_accuracy: 0.9297
# Epoch 107/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.9710 - val_loss: 0.2774 - val_accuracy: 0.9250
# Epoch 108/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0815 - accuracy: 0.9721 - val_loss: 0.2417 - val_accuracy: 0.9250
# Epoch 109/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.9713 - val_loss: 0.2549 - val_accuracy: 0.9238
# Epoch 110/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0774 - accuracy: 0.9715 - val_loss: 0.2243 - val_accuracy: 0.9285
# Epoch 111/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.9724 - val_loss: 0.2549 - val_accuracy: 0.9297
# Epoch 112/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9695 - val_loss: 0.2460 - val_accuracy: 0.9261
# Epoch 113/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9748 - val_loss: 0.2263 - val_accuracy: 0.9273
# Epoch 114/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0839 - accuracy: 0.9689 - val_loss: 0.2546 - val_accuracy: 0.9285
# Epoch 115/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9768 - val_loss: 0.2789 - val_accuracy: 0.9250
# Epoch 116/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0674 - accuracy: 0.9724 - val_loss: 0.2538 - val_accuracy: 0.9273
# Epoch 117/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 0.9789 - val_loss: 0.2477 - val_accuracy: 0.9332
# Epoch 118/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 0.9759 - val_loss: 0.2529 - val_accuracy: 0.9320
# Epoch 119/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9745 - val_loss: 0.2825 - val_accuracy: 0.9273
# Epoch 120/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0757 - accuracy: 0.9736 - val_loss: 0.2815 - val_accuracy: 0.9250
# Epoch 121/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0653 - accuracy: 0.9768 - val_loss: 0.2872 - val_accuracy: 0.9308
# Epoch 122/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0731 - accuracy: 0.9742 - val_loss: 0.2528 - val_accuracy: 0.9297
# Epoch 123/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0600 - accuracy: 0.9765 - val_loss: 0.2599 - val_accuracy: 0.9297
# Epoch 124/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0631 - accuracy: 0.9759 - val_loss: 0.2508 - val_accuracy: 0.9203
# Epoch 125/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0635 - accuracy: 0.9762 - val_loss: 0.2714 - val_accuracy: 0.9261
# Epoch 126/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0619 - accuracy: 0.9792 - val_loss: 0.2784 - val_accuracy: 0.9343
# Epoch 127/200
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0663 - accuracy: 0.9771 - val_loss: 0.2996 - val_accuracy: 0.9261
# Epoch 128/200
# 107/107 [==============================] - 0s 5ms/step - loss: 0.0668 - accuracy: 0.9742 - val_loss: 0.2736 - val_accuracy: 0.9285
# Epoch 129/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9757 - val_loss: 0.2596 - val_accuracy: 0.9226
# Epoch 130/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9748 - val_loss: 0.2494 - val_accuracy: 0.9273
# Epoch 131/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9765 - val_loss: 0.3244 - val_accuracy: 0.9250
# Epoch 132/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0640 - accuracy: 0.9768 - val_loss: 0.2814 - val_accuracy: 0.9320
# Epoch 133/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0608 - accuracy: 0.9757 - val_loss: 0.2455 - val_accuracy: 0.9250
# Epoch 134/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 0.9801 - val_loss: 0.2650 - val_accuracy: 0.9273
# Epoch 135/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0581 - accuracy: 0.9798 - val_loss: 0.2735 - val_accuracy: 0.9285
# Epoch 136/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0602 - accuracy: 0.9774 - val_loss: 0.2946 - val_accuracy: 0.9332
# Epoch 137/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0483 - accuracy: 0.9818 - val_loss: 0.2805 - val_accuracy: 0.9332
# Epoch 138/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 0.9792 - val_loss: 0.2635 - val_accuracy: 0.9355
# Epoch 139/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0575 - accuracy: 0.9803 - val_loss: 0.2466 - val_accuracy: 0.9285
# Epoch 140/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 0.9771 - val_loss: 0.2794 - val_accuracy: 0.9308
# Epoch 141/200
# 107/107 [==============================] - 1s 6ms/step - loss: 0.0607 - accuracy: 0.9751 - val_loss: 0.2784 - val_accuracy: 0.9308
# Epoch 142/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0480 - accuracy: 0.9836 - val_loss: 0.2904 - val_accuracy: 0.9261
# Epoch 143/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9833 - val_loss: 0.3106 - val_accuracy: 0.9273
# Epoch 144/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9809 - val_loss: 0.2896 - val_accuracy: 0.9332
# Epoch 145/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9803 - val_loss: 0.3156 - val_accuracy: 0.9297
# Epoch 146/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0628 - accuracy: 0.9759 - val_loss: 0.3180 - val_accuracy: 0.9261
# Epoch 147/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0614 - accuracy: 0.9768 - val_loss: 0.2516 - val_accuracy: 0.9332
# Epoch 148/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9850 - val_loss: 0.3013 - val_accuracy: 0.9273
# Epoch 149/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0526 - accuracy: 0.9806 - val_loss: 0.2901 - val_accuracy: 0.9250
# Epoch 150/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9801 - val_loss: 0.2403 - val_accuracy: 0.9297
# Epoch 151/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.9859 - val_loss: 0.3007 - val_accuracy: 0.9332
# Epoch 152/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9842 - val_loss: 0.3398 - val_accuracy: 0.9238
# Epoch 153/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0471 - accuracy: 0.9845 - val_loss: 0.2884 - val_accuracy: 0.9297
# Epoch 154/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0449 - accuracy: 0.9859 - val_loss: 0.2539 - val_accuracy: 0.9285
# Epoch 155/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0511 - accuracy: 0.9815 - val_loss: 0.2984 - val_accuracy: 0.9273
# Epoch 156/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9824 - val_loss: 0.2919 - val_accuracy: 0.9285
# Epoch 157/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0448 - accuracy: 0.9836 - val_loss: 0.2851 - val_accuracy: 0.9297
# Epoch 158/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9859 - val_loss: 0.3048 - val_accuracy: 0.9297
# Epoch 159/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9839 - val_loss: 0.2400 - val_accuracy: 0.9191
# Epoch 160/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9789 - val_loss: 0.2529 - val_accuracy: 0.9297
# Epoch 161/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 0.9830 - val_loss: 0.2856 - val_accuracy: 0.9273
# Epoch 162/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 0.9845 - val_loss: 0.2947 - val_accuracy: 0.9332
# Epoch 163/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0459 - accuracy: 0.9833 - val_loss: 0.2902 - val_accuracy: 0.9355
# Epoch 164/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 0.9812 - val_loss: 0.2397 - val_accuracy: 0.9343
# Epoch 165/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0408 - accuracy: 0.9859 - val_loss: 0.2632 - val_accuracy: 0.9320
# Epoch 166/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9783 - val_loss: 0.2802 - val_accuracy: 0.9273
# Epoch 167/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 0.9880 - val_loss: 0.3231 - val_accuracy: 0.9285
# Epoch 168/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0598 - accuracy: 0.9806 - val_loss: 0.2971 - val_accuracy: 0.9250
# Epoch 169/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0423 - accuracy: 0.9856 - val_loss: 0.2899 - val_accuracy: 0.9261
# Epoch 170/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0499 - accuracy: 0.9836 - val_loss: 0.3096 - val_accuracy: 0.9308
# Epoch 171/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0429 - accuracy: 0.9842 - val_loss: 0.3153 - val_accuracy: 0.9261
# Epoch 172/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9795 - val_loss: 0.2961 - val_accuracy: 0.9320
# Epoch 173/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 0.9862 - val_loss: 0.2625 - val_accuracy: 0.9285
# Epoch 174/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 0.9830 - val_loss: 0.2870 - val_accuracy: 0.9297
# Epoch 175/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 0.9842 - val_loss: 0.2668 - val_accuracy: 0.9308
# Epoch 176/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9836 - val_loss: 0.2978 - val_accuracy: 0.9308
# Epoch 177/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0288 - accuracy: 0.9900 - val_loss: 0.3274 - val_accuracy: 0.9226
# Epoch 178/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9865 - val_loss: 0.3167 - val_accuracy: 0.9320
# Epoch 179/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0513 - accuracy: 0.9812 - val_loss: 0.3027 - val_accuracy: 0.9297
# Epoch 180/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9845 - val_loss: 0.3141 - val_accuracy: 0.9320
# Epoch 181/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.9845 - val_loss: 0.3121 - val_accuracy: 0.9285
# Epoch 182/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9856 - val_loss: 0.2754 - val_accuracy: 0.9320
# Epoch 183/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9909 - val_loss: 0.3203 - val_accuracy: 0.9285
# Epoch 184/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 0.9859 - val_loss: 0.3447 - val_accuracy: 0.9273
# Epoch 185/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0460 - accuracy: 0.9809 - val_loss: 0.2906 - val_accuracy: 0.9250
# Epoch 186/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9874 - val_loss: 0.3662 - val_accuracy: 0.9308
# Epoch 187/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9812 - val_loss: 0.3004 - val_accuracy: 0.9238
# Epoch 188/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 0.9909 - val_loss: 0.2976 - val_accuracy: 0.9297
# Epoch 189/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 0.9871 - val_loss: 0.3223 - val_accuracy: 0.9215
# Epoch 190/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9894 - val_loss: 0.2791 - val_accuracy: 0.9308
# Epoch 191/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0312 - accuracy: 0.9889 - val_loss: 0.2760 - val_accuracy: 0.9285
# Epoch 192/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0378 - accuracy: 0.9856 - val_loss: 0.2989 - val_accuracy: 0.9297
# Epoch 193/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0321 - accuracy: 0.9862 - val_loss: 0.3041 - val_accuracy: 0.9226
# Epoch 194/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9894 - val_loss: 0.3441 - val_accuracy: 0.9297
# Epoch 195/200
# 107/107 [==============================] - 0s 3ms/step - loss: 0.0397 - accuracy: 0.9850 - val_loss: 0.3164 - val_accuracy: 0.9273
# Epoch 196/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9891 - val_loss: 0.3238 - val_accuracy: 0.9320
# Epoch 197/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0407 - accuracy: 0.9859 - val_loss: 0.2704 - val_accuracy: 0.9285
# Epoch 198/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9830 - val_loss: 0.2838 - val_accuracy: 0.9203
# Epoch 199/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0348 - accuracy: 0.9868 - val_loss: 0.3496 - val_accuracy: 0.9238
# Epoch 200/200
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 0.9839 - val_loss: 0.2903 - val_accuracy: 0.9261

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.evaluate(X_test, Y_test, verbose=2)
# Out:
# 34/34 - 0s - loss: 0.2476 - accuracy: 0.9400 - 66ms/epoch - 2ms/step
# [0.24762919545173645, 0.9399625062942505]

# %%
# confusion matrix

import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

Y_pred = model.predict(X_test)
cm = confusion_matrix([np.argmax(a) for a in Y_test], [np.argmax(a) for a in Y_pred])

df_cm = pd.DataFrame(cm, index=["Water", "Object"], columns=["Water", "Object"])
plt.figure(figsize=(10, 7))
sn.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
def plot_windmills(left_top_coord, size=(1200, 800), intensity=1):
    (img_h, img_w) = size
    left_top_x, left_top_y = dataset_raw.index(left_top_coord[0], left_top_coord[1])
    needles = []
    step_size = 15

    x_count = ((img_h - block_size) // step_size)
    for xx in range(left_top_x + block_size // 2, left_top_x + img_w - block_size // 2, step_size):
        for yy in range(left_top_y + block_size // 2, left_top_y + img_h - block_size // 2, step_size):
            cc = dataset_raw.transform * (yy, xx)
            lx, ly = dataset_land.index(cc[0], cc[1])
            if img_land[lx, ly] != 1:
                continue
            needles.append({'lon': cc[0], 'lat': cc[1]})

    test_images = np.stack([get_processed_image(coord) for coord in needles])
    results = model.predict(test_images)

    from matplotlib import pyplot as plt

    search_space = np.copy(img_raw[left_top_x:left_top_x + img_w, left_top_y:left_top_y + img_h])
    search_space = search_space ** (1 / 4)
    highlight = np.max(search_space) * 0.75 * intensity

    found = 0
    previous_i = 0
    coords = []
    found_i = []
    for i, result in enumerate(results):
        if result[1] > result[0]:
            if (i - previous_i <= 2):
                continue
            if (i - x_count in found_i or (i - (x_count * 2)) in found_i or (i + 1 - x_count) in found_i or (i - 1 - x_count) in found_i):
                continue
            found += 1
            previous_i = i
            found_i.append(i)
            coord = needles[i]
            xx, yy = dataset_raw.index(coord['lon'], coord['lat'])
            xx -= left_top_x
            yy -= left_top_y

            search_space[xx - block_size // 2:xx + block_size // 2, yy - block_size // 2] = highlight
            search_space[xx - block_size // 2:xx + block_size // 2, yy + block_size // 2] = highlight
            search_space[xx - block_size // 2, yy - block_size // 2:yy + block_size // 2] = highlight
            search_space[xx + block_size // 2, yy - block_size // 2:yy + block_size // 2] = highlight
            coords.append(coord)


    print("found {} windmills".format(found))

    plt.rcParams['figure.figsize'] = [20, 10]
    plt.imshow(search_space)

    return coords

# %%
# vb boten
plot_windmills((2.56834, 51.48205))
# Out:
# found 50 windmills
# [{'lon': 2.6734393328858834, 'lat': 51.47366962760338},
#  {'lon': 2.677646589350599, 'lat': 51.47156599937102},
#  {'lon': 1.8719569763574933, 'lat': 51.92286437615289},
#  {'lon': 1.8929932586810734, 'lat': 51.92286437615289},
#  {'lon': 1.9266513103988008, 'lat': 51.92286437615289},
#  {'lon': 1.9624129903488867, 'lat': 51.92286437615289},
#  {'lon': 1.9329621950958746, 'lat': 51.92076074792053},
#  {'lon': 1.9497912209547386, 'lat': 51.92076074792053},
#  {'lon': 1.9729311315106763, 'lat': 51.92076074792053},
#  {'lon': 1.9897601573695403, 'lat': 51.92076074792053},
#  {'lon': 1.8782678610545676, 'lat': 51.91865711968817},
#  {'lon': 1.8908896304487153, 'lat': 51.91865711968817},
#  {'lon': 1.9182367974693688, 'lat': 51.91865711968817},
#  {'lon': 1.9371694515605908, 'lat': 51.91865711968817},
#  {'lon': 1.9582057338841705, 'lat': 51.91865711968817},
#  {'lon': 2.006589183228404, 'lat': 51.91865711968817},
#  {'lon': 2.02131458085491, 'lat': 51.91865711968817},
#  {'lon': 1.8635424634280617, 'lat': 51.916553491455815},
#  {'lon': 1.922444053934085, 'lat': 51.916553491455815},
#  {'lon': 1.9455839644900228, 'lat': 51.916553491455815},
#  {'lon': 1.9834492726724664, 'lat': 51.916553491455815},
#  {'lon': 2.0107964396931197, 'lat': 51.916553491455815},
#  {'lon': 1.8803714892869252, 'lat': 51.91444986322345},
#  {'lon': 1.9666202468136025, 'lat': 51.91444986322345},
#  {'lon': 1.8656460916604194, 'lat': 51.9123462349911},
#  {'lon': 1.8887860022163572, 'lat': 51.9123462349911},
#  {'lon': 1.9287549386311589, 'lat': 51.9123462349911},
#  {'lon': 1.9434803362576647, 'lat': 51.9123462349911},
#  {'lon': 1.9813456444401083, 'lat': 51.9123462349911},
#  {'lon': 1.8719569763574933, 'lat': 51.910242606758736},
#  {'lon': 1.914029541004653, 'lat': 51.910242606758736},
#  {'lon': 1.9518948491870967, 'lat': 51.910242606758736},
#  {'lon': 1.9687238750459606, 'lat': 51.910242606758736},
#  {'lon': 2.004485554996046, 'lat': 51.910242606758736}]

# %%
# vb kust
plot_windmills((1.12835, 51.90720))
# Out:
# found 0 windmills
# []

# %%
# het duurt redelijk lang voor dit te runnen
coords = plot_windmills((1.4378, 52.1898), (1200 * 5, 800 * 5), intensity=2)
# Out:
# found 649 windmills

# %%
from sklearn import cluster
import matplotlib.cm as cm

colors = np.array(['r', 'g', 'b', 'y', 'c', 't'])
colors = cm.rainbow(np.linspace(0, 1, 50))


def apply(X, algo):
    algo.fit(X)
    labels = algo.labels_.astype(np.int)
    plt.scatter(X[:, 0], X[:, 1], color=colors[labels])
    plt.show()
    return labels


df = pd.DataFrame(coords)
X = df.to_numpy()

#labels = apply(X, cluster.KMeans(n_clusters=4))

labels = apply(X, cluster.DBSCAN(eps=.06))
#apply(X, cluster.SpectralClustering(n_clusters=2, affinity="nearest_neighbors"))

cluster_map = pd.DataFrame()
cluster_map['X'] = X[:, 0]
cluster_map['Y'] = X[:, 1]
cluster_map['cluster'] = labels

print(cluster_map)
# Out:
# /tmp/ipykernel_16206/3793571605.py:10: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   labels = algo.labels_.astype(np.int)
#             X          Y  cluster
# 0    1.744898  52.183574       -1
# 1    1.744898  52.181470       -1
# 2    1.959468  52.173056        0
# 3    1.906877  52.170952        0
# 4    1.961572  52.170952        0
# ..        ...        ...      ...
# 644  1.473530  51.632423        5
# 645  1.488255  51.632423        5
# 646  1.494566  51.632423        5
# 647  1.513499  51.632423        5
# 648  1.555571  51.632423        5
#
# [649 rows x 3 columns]

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer

# Generate synthetic dataset with 8 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)
# X, y = make_blobs(n_samples=1000, centers=5, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(4, 10))

visualizer.fit(X)  # Fit the data to the visualizer
visualizer.show()  # Finalize and render the figure

from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.cluster import KMeans

model = SilhouetteVisualizer(KMeans(5))
model.fit(X)
model.show()

from yellowbrick.cluster import InterclusterDistance

visualizer = InterclusterDistance(model)
visualizer.fit(X)  # Fit the data to the visualizer
visualizer.show()  # Finalize and render the figure

print(len(X))
# Out:
# Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x7fea921acc10>
# Traceback (most recent call last):
#   File "/home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/threadpoolctl.py", line 548, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/threadpoolctl.py", line 669, in _make_controller_from_path
#     lib_controller = lib_controller_class(
#   File "/home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/threadpoolctl.py", line 786, in __init__
#     super().__init__(**kwargs)
#   File "/home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/threadpoolctl.py", line 754, in __init__
#     self._dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
#   File "/usr/lib/python3.9/ctypes/__init__.py", line 374, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: /home/rudolf/Projects/cs-ml-windmill/venv/lib/python3.9/site-packages/numpy.libs/libopenblasp-r0-2d23e62b.3.17.so: cannot open shared object file: No such file or directory
# 649

# %%
from shapely.geometry import LineString
import geopandas as gpd


def bounding_box(x_coordinates, y_coordinates):
    # x_coordinates, y_coordinates = zip(*points)
    return [(min(x_coordinates), min(y_coordinates)), (max(x_coordinates), max(y_coordinates))]


list_lon = []
list_lat = []
list_geom = []

column_values = cluster_map["cluster"].values
clusters = np.unique(column_values)
bboxs = []
for cluster in clusters:
    if (cluster_map[cluster_map.cluster == cluster].shape[0] <= 20):
        continue
    bboxs.append(bounding_box(cluster_map[cluster_map.cluster == cluster]['X'],
                              cluster_map[cluster_map.cluster == cluster]['Y']))

l_lats = []
l_lons = []
boxes = []
for bbox in bboxs:
    l_lats.append(bbox[0][0])
    l_lats.append(bbox[1][0])
    l_lats.append(bbox[1][0])
    l_lats.append(bbox[0][0])
    l_lats.append(bbox[0][0])
    l_lons.append(bbox[0][1])
    l_lons.append(bbox[0][1])
    l_lons.append(bbox[1][1])
    l_lons.append(bbox[1][1])
    l_lons.append(bbox[0][1])

    bb = gpd.points_from_xy(l_lats, l_lons, crs="EPSG:4326")

    boxes.append(LineString(bb))
    l_lats = []
    l_lons = []

df_result = gpd.GeoDataFrame({
    'geometry': boxes
})

df_result['geometry']
from shapely.ops import unary_union

cu = unary_union(df_result['geometry']);
df2_result = gpd.GeoDataFrame({
    'geometry': cu
})

df2_result.crs = 'epsg:4326'
df2_result.to_file("result.shp")
